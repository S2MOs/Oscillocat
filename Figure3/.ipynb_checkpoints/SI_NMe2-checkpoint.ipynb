# %% [markdown]
# ### Figure SI - Data analysis
#
# **Author:** Quentin Duez
#
# This notebook analyses ESI-MS data and extracts relative time delays and amplitudes of propagating perturbations for the experiment involving p-NMe2 cinnamaldehyde.
#
# **Outputs:** Figure S5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score
import seaborn as sns; sns.set_theme(style='ticks', context='paper')

TIMEBIN = 15 # ~1bin = 30s
Ald_conc = 5 #mM
Cat_conc = 2 #mM
Cyclo_conc = 250 #mM

# %%
#Fitting functions
def sinfunc(t, A, w, p, c):
    return A * np.sin(np.pi*(t - p)/w) + c
    #return A * np.sin(w*t + p) + c

def fit_sin(tt, yy, PERIOD): #Scooped from https://stackoverflow.com/questions/16716302/how-do-i-fit-a-sine-curve-to-my-data-with-pylab-and-numpy
    '''Fit sin to the input time sequence, and return fitting parameters "amp", "omega", "phase", "offset", "freq", "period" and "fitfunc"'''
    tt = np.array(tt)
    yy = np.array(yy)
    ff = np.fft.fftfreq(len(tt), (tt[1]-tt[0]))   # assume uniform spacing
    Fyy = abs(np.fft.fft(yy))
    #guess_freq = 1./ PERIOD
    # excluding the zero frequency "peak", which is related to offset
    guess_amp = np.std(yy) * 2.**0.5
    guess_offset = np.mean(yy)
    guess = np.array([guess_amp, PERIOD/2, 0., guess_offset]) #Guess phase = 0; check what works better

    popt, pcov = curve_fit(sinfunc, tt, yy, p0=guess, 
                           bounds=((0, (PERIOD-0.0001)/2, -np.inf, -np.inf), (np.inf, (PERIOD+0.0001)/2, np.inf, np.inf)))
    A, w, p, c = popt
    f = w/(2.*np.pi)
    period = w*2
    fitfunc = lambda t: A * np.sin(np.pi*(t - p)/w) + c
    return {"amp": A, "omega": w, "phase": p, "offset": c, "freq": f, "period": period, "fitfunc": fitfunc, "maxcov": np.max(pcov), "rawres": (guess,popt,pcov)}

def fit_sin_CSTR(t, conc, eq_time, PERIOD):
    t_filtered = t[eq_time:]
    conc_filtered = conc[eq_time:]

    res = fit_sin(t_filtered, conc_filtered, PERIOD)
    ypred = sinfunc(t_filtered,res["amp"],res["omega"],res["phase"],res["offset"])
    r2 = r2_score(conc_filtered, ypred)
    #print(r2_score(conc_filtered, ypred))
    phase = res['phase']
    amp = res['amp']
    
    if abs(phase) > PERIOD:
        ntot = abs(phase) / PERIOD
        nunits = ntot // 1
        if nunits > 0:
            coma = ntot - nunits
        else:
            coma = 0
        phase = coma * PERIOD
    else:
        phase = phase

    if r2 > 0.1: #Condition for not trying to interpret weird data
        rel_amp = abs(res['amp']) / res['offset'] #Calculate the amplitude of the oscillation relative to the ion signal
    
        #Get time delay from the phase (empirically determined, was tricky for me brain)
        if (res['amp'] > 0) & (phase > 0):
            delay = phase + 0.5*res['omega']
        elif (res['amp'] > 0) & (phase < 0):
            delay = phase + 2.5*res['omega']
        else:
            pass
    else:
        rel_amp = 0
        delay = 0
        phase = 0
        
    return(rel_amp, delay, r2, phase, amp)

# %%
#Reading flow profile
profile = pd.read_excel("data/250430_Iminium20.xlsx")
profile = profile.iloc[:, :profile.columns.get_loc('Concentration')] #Dropping everything after "Concentration"
profile = profile.iloc[:, profile.columns.get_loc('Flow') + 1:] #Dropping everything before "Flow"
profile = profile.drop(columns=["Time"])
profile.set_index("Cumul. Time", inplace = True)
profile["Aldehyde_conc"] = (profile["Aldehyde"]*Ald_conc) / profile.sum(axis=1)
profile["Aldehyde_conc_rel"] = profile["Aldehyde_conc"] / profile["Aldehyde_conc"].mean()
profile = profile.dropna()

profile.index = profile.index - 220

print(profile)
# Out:
#              Aldehyde     Cat     MeOH1     MeOH2     MeOH3  Aldehyde_conc  \
# Cumul. Time
# -220.0       5.766600  5.7666  5.766711  5.766711  5.766711       0.999988
# -130.0       5.766600  5.7666  5.766711  5.766711  5.766711       0.999988
# -129.9       5.826987  5.7666  5.746582  5.746582  5.746582       1.010460
# -129.8       5.887367  5.7666  5.726456  5.726456  5.726456       1.020931
# -129.7       5.947733  5.7666  5.706333  5.706333  5.706333       1.031399
# ...               ...     ...       ...       ...       ...            ...
#  739.8       5.706213  5.7666  5.786840  5.786840  5.786840       0.989517
#  739.9       5.736406  5.7666  5.776776  5.776776  5.776776       0.994753
#  740.0       5.766600  5.7666  5.766711  5.766711  5.766711       0.999988
#  830.0       5.766600  5.7666  5.766711  5.766711  5.766711       0.999988
# -220.0       5.766600  5.7666  5.766711  5.766711  5.766711       0.999988
#
#              Aldehyde_conc_rel
# Cumul. Time
# -220.0                1.000000
# -130.0                1.000000
# -129.9                1.010472
# -129.8                1.020942
# -129.7                1.031411
# ...                        ...
#  739.8                0.989528
#  739.9                0.994764
#  740.0                1.000000
#  830.0                1.000000
# -220.0                1.000000
#
# [7806 rows x 7 columns]

# %%
#Reading data
data = pd.read_excel("data/250430_Iminium20_Data.xlsx", header=0)

data["198_TIC"] = data["IC_198"] / data["TIC"]
data["326_TIC"] = data["IC_326"] / data["TIC"] #326 was saturating a bit, we will not use it
data["483_TIC"] = data["IC_483"] / data["TIC"]
data["549_TIC"] = data["IC_549"] / data["TIC"]
data["651_TIC"] = data["IC_651"] / data["TIC"] #651 could be the product (although super low intensity)

bindata = data.groupby(data.index // TIMEBIN).mean()
bindata = bindata.drop(columns=["TIC"])
bindata.set_index("Time", inplace = True)

rolled_bindata = bindata.rolling(5, center=True).mean()

print(bindata)
# Out:
#                   IC_198        IC_326        IC_483        IC_549  \
# Time
# 0.401400    1.021927e+05  9.394140e+04  4.569328e+05  6.089833e+04
# 1.154400    1.132829e+05  9.124000e+04  1.533905e+05  6.212007e+04
# 1.907400    1.008286e+05  1.011491e+05  3.804916e+05  5.442687e+04
# 2.660400    1.041233e+05  8.864233e+04  2.740753e+05  5.811040e+04
# 3.413400    8.964684e+05  9.434013e+06  2.945344e+08  5.848780e+04
# ...                  ...           ...           ...           ...
# 975.536400  8.229542e+07  1.469497e+09  6.214160e+08  5.726342e+06
# 976.289400  6.878750e+07  1.643206e+09  7.908379e+08  6.439578e+06
# 977.042400  8.471112e+07  1.692261e+09  8.401447e+08  7.852032e+06
# 977.795400  1.232881e+08  2.188447e+09  1.262552e+09  8.763134e+06
# 978.523286  1.137175e+08  1.941877e+09  1.297188e+09  8.544367e+06
#
#                   IC_651   198_TIC   326_TIC   483_TIC   549_TIC   651_TIC
# Time
# 0.401400    1.072667e+05  0.001787  0.001640  0.007572  0.001062  0.001868
# 1.154400    1.188971e+05  0.001982  0.001583  0.002701  0.001086  0.002069
# 1.907400    1.259437e+05  0.001764  0.001770  0.006517  0.000953  0.002202
# 2.660400    1.197173e+05  0.001751  0.001483  0.004689  0.000940  0.001986
# 3.413400    9.720098e+05  0.005335  0.043579  0.071798  0.000456  0.003706
# ...                  ...       ...       ...       ...       ...       ...
# 975.536400  3.714127e+08  0.015737  0.276557  0.117511  0.001101  0.070756
# 976.289400  4.289567e+08  0.011039  0.264519  0.128068  0.001043  0.069650
# 977.042400  4.081122e+08  0.013086  0.260185  0.127182  0.001237  0.063863
# 977.795400  4.959946e+08  0.014576  0.252520  0.148909  0.001033  0.058213
# 978.523286  3.910709e+08  0.014048  0.237002  0.141476  0.000945  0.049697
#
# [1300 rows x 10 columns]

# %%
data_2ndosci = bindata[(bindata.index > 220) & (bindata.index < 1100)]
data_2ndosci["198_TIC_rel"] = data_2ndosci["198_TIC"] / data_2ndosci["198_TIC"].mean()
data_2ndosci["326_TIC_rel"] = data_2ndosci["326_TIC"] / data_2ndosci["326_TIC"].mean()
data_2ndosci["483_TIC_rel"] = data_2ndosci["483_TIC"] / data_2ndosci["483_TIC"].mean()
data_2ndosci["549_TIC_rel"] = data_2ndosci["549_TIC"] / data_2ndosci["549_TIC"].mean()
data_2ndosci["651_TIC_rel"] = data_2ndosci["651_TIC"] / data_2ndosci["651_TIC"].mean()
rolled_data_2ndosci = data_2ndosci.rolling(5, center=True).mean()
rolled_data_2ndosci = rolled_data_2ndosci.dropna()

data_2ndosci.index = data_2ndosci.index - 220
rolled_data_2ndosci.index = rolled_data_2ndosci.index - 220
profile_2ndosci = profile[(profile.index > 0) & (profile.index < 900)]
# Out:
# C:\Users\qduez\AppData\Local\Temp\ipykernel_13104\1396548641.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2ndosci["198_TIC_rel"] = data_2ndosci["198_TIC"] / data_2ndosci["198_TIC"].mean()
# C:\Users\qduez\AppData\Local\Temp\ipykernel_13104\1396548641.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2ndosci["326_TIC_rel"] = data_2ndosci["326_TIC"] / data_2ndosci["326_TIC"].mean()
# C:\Users\qduez\AppData\Local\Temp\ipykernel_13104\1396548641.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2ndosci["483_TIC_rel"] = data_2ndosci["483_TIC"] / data_2ndosci["483_TIC"].mean()
# C:\Users\qduez\AppData\Local\Temp\ipykernel_13104\1396548641.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2ndosci["549_TIC_rel"] = data_2ndosci["549_TIC"] / data_2ndosci["549_TIC"].mean()
# C:\Users\qduez\AppData\Local\Temp\ipykernel_13104\1396548641.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2ndosci["651_TIC_rel"] = data_2ndosci["651_TIC"] / data_2ndosci["651_TIC"].mean()

# %%
fig, ax = plt.subplots(5,1, figsize=(7.3,3.7))

sns.lineplot(data=profile, x=profile.index, y="Aldehyde_conc_rel", ax=ax[0], label="Input")
sns.scatterplot(data=data_2ndosci, x=data_2ndosci.index, y="198_TIC_rel", markers=["o"], alpha = 0.5, s=7,linewidth=0, ax=ax[1], c='tab:blue')
sns.lineplot(data=rolled_data_2ndosci, x=rolled_data_2ndosci.index, y="198_TIC_rel", ax=ax[1], linewidth=1.5, label="$\it{m/z}$ 198", c='tab:blue')
sns.scatterplot(data=data_2ndosci, x=data_2ndosci.index, y="483_TIC_rel", markers=["o"], alpha = 0.5, s=7,linewidth=0, ax=ax[2], c='tab:green')
sns.lineplot(data=rolled_data_2ndosci, x=rolled_data_2ndosci.index, y="483_TIC_rel", ax=ax[2], linewidth=1.5, label="$\it{m/z}$ 483", c='tab:green')
sns.scatterplot(data=data_2ndosci, x=data_2ndosci.index, y="549_TIC_rel", markers=["o"], alpha = 0.5, s=7,linewidth=0, ax=ax[3], c='tab:orange')
sns.lineplot(data=rolled_data_2ndosci, x=rolled_data_2ndosci.index, y="549_TIC_rel", ax=ax[3], linewidth=1.5, label="$\it{m/z}$ 549", c='tab:orange')
sns.scatterplot(data=data_2ndosci, x=data_2ndosci.index, y="651_TIC_rel", markers=["o"], alpha = 0.5, s=7,linewidth=0, ax=ax[4], c='firebrick')
sns.lineplot(data=rolled_data_2ndosci, x=rolled_data_2ndosci.index, y="651_TIC_rel", ax=ax[4], linewidth=1.5, label="$\it{m/z}$ 651", c='firebrick')

ax[0].set_xlim(0,850)
ax[1].set_xlim(0,850)
ax[2].set_xlim(0,850)
ax[3].set_xlim(0,850)
ax[4].set_xlim(0,850)
ax[1].set_ylim(0.2,1.75)
ax[2].set_ylim(0.2,1.75)
ax[3].set_ylim(0.2,1.75)
ax[4].set_ylim(0.2,1.75)

ax[0].set_ylabel("Conc. (mM)", fontsize = 10)
ax[1].set_ylabel("Norm. Int.", fontsize = 10)
ax[2].set_ylabel("Norm. Int.", fontsize = 10)
ax[3].set_ylabel("Norm. Int.", fontsize = 10)
ax[4].set_ylabel("Norm. Int.", fontsize = 10)

ax[0].set_xlabel('')
ax[1].set_xlabel('')
ax[2].set_xlabel('')
ax[3].set_xlabel('')
ax[4].set_xlabel("Time (min)", fontsize = 10)

ax[0].set_xticklabels("")
ax[1].set_xticklabels("")
ax[2].set_xticklabels("")
ax[3].set_xticklabels("")


fit_198 = fit_sin_CSTR(data_2ndosci.index.to_numpy(), data_2ndosci['198_TIC_rel'].to_numpy(), 50, 120) #50 is 50 min offset time
fit_483 = fit_sin_CSTR(data_2ndosci.index.to_numpy(), data_2ndosci['483_TIC_rel'].to_numpy(), 50, 120) #50 is 50 min offset time
fit_549 = fit_sin_CSTR(data_2ndosci.index.to_numpy(), data_2ndosci['549_TIC_rel'].to_numpy(), 50, 120) #50 is 50 min offset time
fit_651 = fit_sin_CSTR(data_2ndosci.index.to_numpy(), data_2ndosci['651_TIC_rel'].to_numpy(), 50, 120) #50 is 50 min offset time

pred_198 = sinfunc(data_2ndosci.index.to_numpy(), fit_198[4], 60, fit_198[3], 1)
pred_483 = sinfunc(data_2ndosci.index.to_numpy(), fit_483[4], 60, fit_483[3], 1)
pred_549 = sinfunc(data_2ndosci.index.to_numpy(), fit_549[4], 60, fit_549[3], 1)
pred_651 = sinfunc(data_2ndosci.index.to_numpy(), fit_651[4], 60, fit_651[3], 1)

#Uncomment to plot the fitted sinewaves
sns.lineplot(x=data_2ndosci.index.to_numpy(), y=pred_198, ax=ax[1], linewidth=1.5, label="fit", c='tab:purple')
sns.lineplot(x=data_2ndosci.index.to_numpy(), y=pred_483, ax=ax[2], linewidth=1.5, label="fit", c='tab:purple')
sns.lineplot(x=data_2ndosci.index.to_numpy(), y=pred_549, ax=ax[3], linewidth=1.5, label="fit", c='tab:purple')
sns.lineplot(x=data_2ndosci.index.to_numpy(), y=pred_651, ax=ax[4], linewidth=1.5, label="fit", c='tab:purple')

ax[0].legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', fontsize = 9)
ax[1].legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', fontsize = 9)
ax[2].legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', fontsize = 9)
ax[3].legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', fontsize = 9)
ax[4].legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', fontsize = 9)

ax[0].set_facecolor('#F8F8FB')
ax[1].set_facecolor('#F8F8FB')
ax[2].set_facecolor('#F8F8FB')
ax[3].set_facecolor('#F8F8FB')
ax[4].set_facecolor('#F8F8FB')

print("198", fit_198[0:3])
print("483", fit_483[0:3])
print("549", fit_549[0:3])
print("651", fit_651[0:3])

fig.align_ylabels(ax[:])

plt.subplots_adjust(left=None, bottom=None, right=0.6, top=1.1, wspace=None, hspace=0.2)
#plt.savefig('FigureSI_NMe2.svg', format='svg', bbox_inches='tight', dpi=600)
# Out:
# 198 (0.21926072374700756, 75.44866478505787, 0.41103458407267013)
# 483 (0.21004117684883544, 88.46037505730308, 0.4950156548848097)
# 549 (0.10669396183679382, 88.90712439189011, 0.18366374654693396)
# 651 (0.2919344334145725, 136.86058111976425, 0.6473504937285712)
