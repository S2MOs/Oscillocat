# %% [markdown]
# ### Figure 4 - Numerical model
#
# **Author:** Quentin Duez
#
# This notebook builds and analyses a numerical model based on the reaction shown in Figure 3
#
# **Outputs:** Figure 4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score
import seaborn as sns; sns.set_theme(style='ticks', context='paper')
import matplotlib.ticker as mticker

from SALib.sample import sobol
from SALib.analyze.sobol import analyze

# %%
#Reaction network definition
#Two steps reversible reactions : A + B <--> C + D <--> E
def d2_rev_dt(x, t, *args):
    A,B,C,D,E = x
    k1, km1, k2, km2, kf = args
    dAdt = -k1 * A * B + km1 * C + kf * A0_ss*(1 + np.sin(2*np.pi*t/PERIOD)) - kf * A
    dBdt = -k1 * A * B + km1 * C - kf * B + kf * B0_ss
    dCdt = k1 * A * B - km1 * C - k2 * C * D + km2 * E - kf * C
    dDdt = -k2 * C * D + km2 * E - kf * D + kf * D0_ss
    dEdt = k2 * C * D - km2 * E - kf * E
    return dAdt, dBdt, dCdt, dDdt, dEdt

# %%
#Fitting functions
def sinfunc(t, A, w, p, c):
    return A * np.sin(np.pi*(t - p)/w) + c
    #return A * np.sin(w*t + p) + c

def fit_sin(tt, yy, PERIOD): #Scooped from https://stackoverflow.com/questions/16716302/how-do-i-fit-a-sine-curve-to-my-data-with-pylab-and-numpy
    '''Fit sin to the input time sequence, and return fitting parameters "amp", "omega", "phase", "offset", "freq", "period" and "fitfunc"'''
    tt = np.array(tt)
    yy = np.array(yy)
    ff = np.fft.fftfreq(len(tt), (tt[1]-tt[0]))   # assume uniform spacing
    Fyy = abs(np.fft.fft(yy))
    #guess_freq = 1./ PERIOD
    # excluding the zero frequency "peak", which is related to offset
    guess_amp = np.std(yy) * 2.**0.5
    guess_offset = np.mean(yy)
    guess = np.array([guess_amp, PERIOD/2, 0., guess_offset]) #Guess phase = 0; check what works better

    popt, pcov = curve_fit(sinfunc, tt, yy, p0=guess, 
                           bounds=((0, (PERIOD-0.0001)/2, -np.inf, -np.inf), (np.inf, (PERIOD+0.0001)/2, np.inf, np.inf)))
    A, w, p, c = popt
    f = w/(2.*np.pi)
    period = w*2
    fitfunc = lambda t: A * np.sin(np.pi*(t - p)/w) + c
    return {"amp": A, "omega": w, "phase": p, "offset": c, "freq": f, "period": period, "fitfunc": fitfunc, "maxcov": np.max(pcov), "rawres": (guess,popt,pcov)}

def fit_sin_CSTR(t, conc, eq_time, PERIOD):
    t_filtered = t[eq_time:]
    conc_filtered = conc[eq_time:]

    res = fit_sin(t_filtered, conc_filtered, PERIOD)
    ypred = sinfunc(t_filtered,res["amp"],res["omega"],res["phase"],res["offset"])
    r2 = r2_score(conc_filtered, ypred)
    #print(r2_score(conc_filtered, ypred))
    phase = res['phase']
    amp = res['amp']
    
    if abs(phase) > PERIOD:
        ntot = abs(phase) / PERIOD
        nunits = ntot // 1
        if nunits > 0:
            coma = ntot - nunits
        else:
            coma = 0
        phase = coma * PERIOD
    else:
        phase = phase

    if r2 > 0.2: #Condition for not trying to interpret weird data
        rel_amp = abs(res['amp']) / res['offset'] #Calculate the amplitude of the oscillation relative to the ion signal
    
        #Get time delay from the phase (empirically determined, was tricky for me brain)
        if (res['amp'] > 0) & (phase > 0):
            delay = phase + 0.5*res['omega']
        elif (res['amp'] > 0) & (phase < 0):
            delay = phase + 2.5*res['omega']
        else:
            pass
    else:
        rel_amp = 0
        delay = 0
        phase = 0
        
    return(rel_amp, delay, r2, phase, amp)

# %%
#Model evaluation functions for sensitivity analysis

def model_evaluate(model, param_values): 
    fit_df = pd.DataFrame()
    for i, params in enumerate(param_values):
        
        klist = params.tolist()
        t = np.linspace(0, 1000, 1001)
        
        x0 = np.zeros(3*len(klist)-1) #initial conditions
        x0[0] = 0.001 #Define the concentration of the first compound
        sol = odeint(model, x0, t, args=(*klist,kf))
        num_sol = sol.shape[1]
        
        s = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
        s = s[:num_sol]
        
        fit_dict = dict()
        for char in s:
            out = sol[:,s.index(char)]
            fit = fit_sin_CSTR(t, out, eq_time, PERIOD)
            if fit[2] > 0.98:
                fit_dict.update({f'rel_amp_{char}' : fit[0], f'time_delay_{char}' : fit[1]})
            else:
                fit_dict.update({f'rel_amp_{char}' : 1, f'time_delay_{char}' : 0})
                 
        fit_df_temp = pd.DataFrame(fit_dict, index=[0])
        fit_df = pd.concat([fit_df,fit_df_temp])
    
    return fit_df

def model_evaluate_reversible(model, param_values): 
    fit_df = pd.DataFrame()
    for i, params in enumerate(param_values):
        
        klist = params.tolist()
        t = np.linspace(0, 1000, 1001)
        
        x0 = np.zeros(len(klist) + 1) #initial conditions !! Number of compounds different than for nonreversible !!
        x0[0] = 0.001 #Define the concentration of the first compound
        sol = odeint(model, x0, t, args=(*klist,kf))
        num_sol = sol.shape[1]
        
        s = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
        s = s[:num_sol]

        E_avg = sol[:,4].mean()
        C_avg = sol[:,2].mean()
        A_avg = sol[:,0].mean()
        
        fit_dict = dict()
        for char in s:
            out = sol[:,s.index(char)]
            fit = fit_sin_CSTR(t, out, eq_time, PERIOD)
            if (fit[2] > 0.5) & (C_avg > 0.01 * A_avg) & (E_avg > 0.01 * A_avg):
                fit_dict.update({'k1' : klist[0], 'km1' : klist[1], 'k2' : klist[2], 'km2' : klist[3], f'rel_amp_{char}' : fit[0], f'time_delay_{char}' : fit[1]})
            else:
                fit_dict.update({'k1' : klist[0], 'km1' : klist[1], 'k2' : klist[2], 'km2' : klist[3], f'rel_amp_{char}' : 1, f'time_delay_{char}' : 0})
                 
        fit_df_temp = pd.DataFrame(fit_dict, index=[0])
        fit_df = pd.concat([fit_df,fit_df_temp])
    
    return fit_df

# %%
#Initial oscillations
A0_ss = 0.001 #mol/L
B0_ss = 0.0004 # mol/L - For 2nd order reactions
D0_ss = 0.05 # mol/L - For 2nd order reactions
TAU = 30 #minutes - Residence time
PERIOD = 120 #min
kf = 1/TAU # = flowrate (µL/min)/Reactor volume (µL) = 1/residence time (min)
eq_time = 3*TAU #The CSTR should be equilibrated at ~4-5x the residence time

# %% [markdown]
# ### Two steps reversible reaction A + B <--> C + D <--> E

# %%
#With fixed k1, k2

k1 = 10 #M-1 min-1
k2 = 10 #M-1 min-1
km1 = 0.01 #min-1
km2 = 0.01 #min-1

t = np.linspace(0, 1000, 1001)
x0 = 0.001, 0.0004, 0, 0.05, 0 #initial conditions
sol = odeint(d2_rev_dt, x0, t, args=(k1,km1,k2,km2,kf))

sol_noreaction = odeint(d2_rev_dt, x0, t, args=(0,0,0,0,kf)) #model the oscillation when no reaction takes place

A_overlay = sol[:,0] / sol[800:,0].mean()
B_overlay = sol[:,1] / sol[800:,1].mean()
C_overlay = sol[:,2] / sol[800:,2].mean()
D_overlay = sol[:,3] / sol[800:,3].mean()
E_overlay = sol[:,4] / sol[800:,4].mean()

fig, ax = plt.subplots(2,1, figsize=(6, 2))

params = {'mathtext.default': 'regular' }          
plt.rcParams.update(params)
sns.lineplot(x = t, y = A_overlay, ax=ax[1], c='tab:blue', label='1')
sns.lineplot(x = t, y = B_overlay, ax=ax[1], c='firebrick', label='2')
sns.lineplot(x = t, y = C_overlay, ax=ax[1], c='tab:green', label='3')
sns.lineplot(x = t, y = D_overlay, ax=ax[1], c='tab:purple', label='4')
sns.lineplot(x = t, y = E_overlay, ax=ax[1], c='tab:orange', label='5')
sns.lineplot(x = t, y = sol[:,0], ax=ax[0], c='tab:blue', label='1')
sns.lineplot(x = t, y = sol[:,1], ax=ax[0], c='firebrick', label='2')
sns.lineplot(x = t, y = sol[:,2], ax=ax[0], c='tab:green', label='3')
sns.lineplot(x = t, y = sol[:,3], ax=ax[0], c='tab:purple', label='4')
sns.lineplot(x = t, y = sol[:,4], ax=ax[0], c='tab:orange', label='5')

ax[0].set_ylim(0,0.002)
ax[1].set_ylim(0,2)
ax[0].set_xlim(0,780)
ax[1].set_xlim(0,780)


ax[0].set_ylabel("Conc. (mM)", fontsize = 10)
ax[1].set_ylabel("Norm. Conc.", fontsize = 10)
ax[0].set_xlabel("")
ax[1].set_xlabel("Time (min)", fontsize = 10)

ax[0].set_xticklabels("")
fig.align_ylabels(ax[:])

ax[0].legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', fontsize = 9)
ax[1].legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', fontsize = 9)

ax[0].set_facecolor('#F8F8FB')
ax[1].set_facecolor('#F8F8FB')

ax[0].set_title('Model : $k_{1} =\ k_{2} =\ 10 \ M^{-1}.min^{-1} \quad k_{-1} =\ k_{-2} =\ 0.01 \ min^{-1}$', fontsize = 10)

plt.subplots_adjust(left=None, bottom=None, right=None, top=1.2, wspace=None, hspace=0.15)
#plt.savefig('Figure2_model_num.svg', format='svg', bbox_inches='tight', dpi=600)

# %%
fit_A = fit_sin_CSTR(t, A_overlay, 50, 120) #50 is 50 min offset time
fit_C = fit_sin_CSTR(t, C_overlay, 50, 120) #50 is 50 min offset time
fit_E = fit_sin_CSTR(t, E_overlay, 50, 120) #50 is 50 min offset time

print(fit_A[0:3])
print(fit_C[0:3])
print(fit_E[0:3])
# Out:
# (0.569299486324834, 48.595132347215326, 0.9993112188007311)
# (0.4478379992028335, 50.5978577450865, 0.998211293879202)
# (0.2863927927141553, 67.37630482425863, 0.9974131059630627)

# %%
# Define problem
#EXECUTE ONLY TO REGENERATE ALL THE VALUES, OTHERWISE USE THE FOLLOWING CELL TO READ THE ASSOCIATED EXCEL FILE
problem = {
    'num_vars': 4,
    'names': ['k1', 'km1', 'k2', 'km2'],
    'bounds': [[1e-2, 1e3],
               [1e-5, 1e2],
               [1e-2, 1e3],
               [1e-5, 1e2]],
    'dists' : ['logunif','logunif','logunif','logunif'] #Makes logarithmic uniform distribution
}

# Generate parameter samples
param_values = sobol.sample(problem, 8192) #Sampler generated N * (D+2) inputs, N = num_samples and D = num_vars
#print(param_values)

fit_df = model_evaluate_reversible(d2_rev_dt, param_values)

fit_df["rel_amp_AC"] = fit_df["rel_amp_C"] / fit_df["rel_amp_A"]
fit_df["time_delay_AC"] = fit_df["time_delay_C"] - fit_df["time_delay_A"]
fit_df["rel_amp_AE"] = fit_df["rel_amp_E"] / fit_df["rel_amp_A"]
fit_df["time_delay_AE"] = fit_df["time_delay_E"] - fit_df["time_delay_A"]
fit_df['K1'] = fit_df["k1"] / fit_df["km1"]
fit_df['K2'] = fit_df["k2"] / fit_df["km2"]

# %%
#READ THE ASSOCIATED EXCEL FILE TO AVOID REGENERATING ALL THE VALUES
fit_df = pd.read_excel("Figure2_model_full.xlsx", index_col=0)
fit_df = fit_df.reset_index()

# %%
fit_df_pos = fit_df[(fit_df.time_delay_AC > 0) & (fit_df.time_delay_AE > 0)]

fig, ax = plt.subplots(figsize=(3,3))
sns.scatterplot(data=fit_df_pos, x="K1", y="K2", hue="time_delay_AC", s=5, linewidth=0)
ax.set_facecolor('#F8F8FB')
ax.legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', markerscale=2)
ax.set_title("Time delay 3-1 (min)", fontsize = 10)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('$K_{1}$', fontsize = 10)
ax.set_ylabel('$K_{2}$', fontsize = 10)
ax.xaxis.set_minor_locator(mticker.LogLocator(numticks=999, subs="auto"))
plt.savefig('Figure2_model_Timedelay_1-3.svg', format='svg', bbox_inches='tight', dpi=600)

# %%
fit_df_pos = fit_df[(fit_df.time_delay_AC > 0) & (fit_df.time_delay_AE > 0)]

fig, ax = plt.subplots(figsize=(3,3))
sns.scatterplot(data=fit_df_pos, x="K1", y="K2", hue="time_delay_AE", s=5, linewidth=0)
ax.set_facecolor('#F8F8FB')
ax.legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', markerscale=2)
ax.set_title("Time delay 5-1 (min)", fontsize = 10)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('$K_{1}$', fontsize = 10)
ax.set_ylabel('$K_{2}$', fontsize = 10)
ax.xaxis.set_minor_locator(mticker.LogLocator(numticks=999, subs="auto"))

plt.savefig('Figure2_model_Timedelay_1-5.svg', format='svg', bbox_inches='tight', dpi=600)

# %%
fit_df_pos = fit_df[(fit_df.time_delay_AC > 0) & (fit_df.time_delay_AE > 0)]

fig, ax = plt.subplots(figsize=(3,3))
sns.scatterplot(data=fit_df_pos, x="k1", y="km1", hue="time_delay_AC", s=5, linewidth=0)
ax.set_facecolor('#F8F8FB')
ax.legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', markerscale=2)
ax.set_title("Time delay 3-1 (min)", fontsize = 10)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('$k_{1}$', fontsize = 10)
ax.set_ylabel('$k_{-1}$', fontsize = 10)
plt.savefig('Figure2_model_k1_km1_Timedelay_1-3.svg', format='svg', bbox_inches='tight', dpi=600)

# %%
fit_df_pos = fit_df[(fit_df.time_delay_AC > 0) & (fit_df.time_delay_AE > 0)]

fig, ax = plt.subplots(figsize=(3,3))
sns.scatterplot(data=fit_df_pos, x="k2", y="km2", hue="time_delay_AC", s=5, linewidth=0)
ax.set_facecolor('#F8F8FB')
ax.legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', markerscale=2)
ax.set_title("Time delay 3-1 (min)", fontsize = 10)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('$k_{2}$', fontsize = 10)
ax.set_ylabel('$k_{-2}$', fontsize = 10)
plt.savefig('Figure2_model_k2_km2_Timedelay_1-3.svg', format='svg', bbox_inches='tight', dpi=600)

# %%
fit_df_pos = fit_df[(fit_df.time_delay_AC > 0) & (fit_df.time_delay_AE > 0)]

fig, ax = plt.subplots(figsize=(3,3))
sns.scatterplot(data=fit_df_pos, x="k1", y="km1", hue="time_delay_AE", s=5, linewidth=0)
ax.set_facecolor('#F8F8FB')
ax.legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', markerscale=2)
ax.set_title("Time delay 5'-1 (min)", fontsize = 10)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('$k_{1}$', fontsize = 10)
ax.set_ylabel('$k_{-1}$', fontsize = 10)
plt.savefig('Figure2_model_k1_km1_Timedelay_1-5.svg', format='svg', bbox_inches='tight', dpi=600)

# %%
fit_df_pos = fit_df[(fit_df.time_delay_AC > 0) & (fit_df.time_delay_AE > 0)]

fig, ax = plt.subplots(figsize=(3,3))
sns.scatterplot(data=fit_df_pos, x="k2", y="km2", hue="time_delay_AE", s=5, linewidth=0)
ax.set_facecolor('#F8F8FB')
ax.legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', markerscale=2)
ax.set_title("Time delay 5'-1 (min)", fontsize = 10)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('$k_{2}$', fontsize = 10)
ax.set_ylabel('$k_{-2}$', fontsize = 10)
plt.savefig('Figure2_model_k2_km2_Timedelay_1-5.svg', format='svg', bbox_inches='tight', dpi=600)

# %%
#Check the datapoints where the time delay between A and C and E matches the experimental value
#out_df = fit_df_pos.loc[(fit_df_pos['time_delay_AC'] > -4.22) & (fit_df_pos['time_delay_AC'] < -4.02)]# & (fit_df_pos['time_delay_AE'] < 19.17) & (fit_df_pos['time_delay_AE'] > 18.97)]
#out_df = fit_df_pos.loc[(fit_df_pos['time_delay_AC'] < 0) & (fit_df_pos['time_delay_AE'] < 20) & (fit_df_pos['time_delay_AE'] > 18)]

out_df = fit_df_pos.loc[(fit_df_pos['time_delay_AC'] > 3) & (fit_df_pos['time_delay_AC'] < 5) & (fit_df_pos['time_delay_AE'] < 19.17) & (fit_df_pos['time_delay_AE'] > 18.97)]

print(out_df)

print(out_df.k1.mean(), out_df.k1.std())
print(out_df.km1.mean(), out_df.km1.std())

sns.scatterplot(out_df, x="k1", y="km1")
# Out:
#            k1       km1        k2       km2  rel_amp_A  time_delay_A  \
# 0  225.704512  0.003629  0.313600  0.013183   0.704691     48.619673
# 0  539.367282  0.000428  0.018646  0.003358   0.769023     48.936781
# 0  502.443781  0.000028  0.020128  0.004315   0.765293     48.918226
#
#    rel_amp_B  time_delay_B  rel_amp_C  time_delay_C  rel_amp_D  time_delay_D  \
# 0   0.578622    114.511463   0.191310     51.733036          1             0
# 0   0.778460    112.420620   0.108806     52.120870          1             0
# 0   0.765996    112.581028   0.112250     52.267589          1             0
#
#    rel_amp_E  time_delay_E  rel_amp_AC  time_delay_AC  rel_amp_AE  \
# 0   0.130013     67.650014    0.271480       3.113363    0.184496
# 0   0.067160     68.008014    0.141487       3.184089    0.087332
# 0   0.070059     68.085109    0.146676       3.349363    0.091546
#
#    time_delay_AE            K1         K2
# 0      19.030341  6.219214e+04  23.789088
# 0      19.071234  1.261182e+06   5.552431
# 0      19.166883  1.825709e+07   4.664418
# 422.5051917167976 171.4313763217775
# 0.001361445545351307 0.001974053219748343
# <Axes: xlabel='k1', ylabel='km1'>

# %% [markdown]
# ### Probe sensitivity for a smaller range of k

# %%
# Define problem
problem = {
    'num_vars': 4,
    'names': ['k1', 'km1', 'k2', 'km2'],
    'bounds': [[1e-1, 1e2],
               [1e-5, 1e2],
               [1e-0, 1e3],
               [1e-5, 1e2]],
    'dists' : ['logunif','logunif','logunif','logunif'] #Makes logarithmic uniform distribution
}

# Generate parameter samples
param_values = sobol.sample(problem, 2048) #Sampler generated N * (D+2) inputs, N = num_samples and D = num_vars
#print(param_values)

fit_df = model_evaluate_reversible(d2_rev_dt, param_values)

fit_df["rel_amp_AC"] = fit_df["rel_amp_C"] / fit_df["rel_amp_A"]
fit_df["time_delay_AC"] = fit_df["time_delay_C"] - fit_df["time_delay_A"]
fit_df["rel_amp_AE"] = fit_df["rel_amp_E"] / fit_df["rel_amp_A"]
fit_df["time_delay_AE"] = fit_df["time_delay_E"] - fit_df["time_delay_A"]

# %%
fit_df.to_excel("k1_km1_k2_km2_smallerrange_2_rev.xlsx")

# %%
fit_df_pos = fit_df[(fit_df.time_delay_AC > -10) & (fit_df.time_delay_AE > -10)]

fig, ax = plt.subplots(figsize=(3,3))
sns.scatterplot(data=fit_df_pos, x="k1", y="km1", hue="time_delay_AC", s=5, linewidth=0)
ax.set_facecolor('#F8F8FB')
ax.legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', markerscale=2)
ax.set_title("Time delay 3-1 (min)", fontsize = 10)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('$k_{1}$', fontsize = 10)
ax.set_ylabel('$k_{-1}$', fontsize = 10)
# Out:
# Text(0, 0.5, '$k_{-1}$')

# %%
fig, ax = plt.subplots(figsize=(3,3))
sns.scatterplot(data=fit_df_pos, x="k2", y="km2", hue="time_delay_AC", s=5, linewidth=0)
ax.set_facecolor('#F8F8FB')
ax.legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', markerscale=2)
ax.set_title("Time delay 3-1 (min)", fontsize = 10)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('$k_{2}$', fontsize = 10)
ax.set_ylabel('$k_{-2}$', fontsize = 10)
# Out:
# Text(0, 0.5, '$k_{-2}$')

# %%
fig, ax = plt.subplots(figsize=(3,3))
sns.scatterplot(data=fit_df_pos, x="k1", y="km1", hue="time_delay_AE", s=5, linewidth=0)
ax.set_facecolor('#F8F8FB')
ax.legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', markerscale=2)
ax.set_title("Time delay 5-1 (min)", fontsize = 10)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('$k_{1}$', fontsize = 10)
ax.set_ylabel('$k_{-1}$', fontsize = 10)
# Out:
# Text(0, 0.5, '$k_{-1}$')

# %%
fig, ax = plt.subplots(figsize=(3,3))
sns.scatterplot(data=fit_df_pos, x="k2", y="km2", hue="time_delay_AE", s=5, linewidth=0)
ax.set_facecolor('#F8F8FB')
ax.legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', markerscale=2)
ax.set_title("Time delay 5-1 (min)", fontsize = 10)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('$k_{2}$', fontsize = 10)
ax.set_ylabel('$k_{-2}$', fontsize = 10)
# Out:
# Text(0, 0.5, '$k_{-2}$')

# %%
#objective = rel_amp_AC, rel_amp_AB, time_delay_AC, time_delay_AB
Y = fit_df["time_delay_AE"].to_numpy()

# Perform Sobol analysis
print("Time delay AE")
Si = analyze(problem, Y, calc_second_order=True, print_to_console=True)
# Out:
# Time delay AE
#            ST   ST_conf
# k1   0.368600  0.043204
# km1  0.638884  0.057561
# k2   0.516138  0.053288
# km2  0.436288  0.044566
#            S1   S1_conf
# k1   0.030608  0.041051
# km1  0.232252  0.058237
# k2   0.070111  0.048826
# km2  0.068697  0.038389
#                   S2   S2_conf
# (k1, km1)   0.029690  0.060398
# (k1, k2)    0.098199  0.054138
# (k1, km2)   0.021041  0.056193
# (km1, k2)   0.031969  0.077561
# (km1, km2)  0.081438  0.073723
# (k2, km2)   0.072311  0.068489
# C:\Users\qduez\miniconda3\lib\site-packages\SALib\util\__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))

# %%
#objective = rel_amp_AC, rel_amp_AB, time_delay_AC, time_delay_AB
Y = fit_df["time_delay_AC"].to_numpy()

# Perform Sobol analysis
print("Time delay AC")
Si = analyze(problem, Y, calc_second_order=True, print_to_console=True)
# Out:
# Time delay AC
#            ST   ST_conf
# k1   0.629725  0.050896
# km1  0.465441  0.045825
# k2   0.420012  0.044453
# km2  0.487884  0.051659
#            S1   S1_conf
# k1   0.121043  0.053884
# km1  0.076386  0.048071
# k2   0.064099  0.042221
# km2  0.122669  0.039902
#                   S2   S2_conf
# (k1, km1)   0.147446  0.086855
# (k1, k2)    0.059662  0.081911
# (k1, km2)   0.097502  0.068186
# (km1, k2)   0.016952  0.058127
# (km1, km2)  0.017650  0.054130
# (k2, km2)   0.016202  0.052116
# C:\Users\qduez\miniconda3\lib\site-packages\SALib\util\__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))

# %% [markdown]
# ### Probe sensitivity for fixed k-1

# %%
# Define problem
problem = {
    'num_vars': 4,
    'names': ['k1', 'km1', 'k2', 'km2'],
    'bounds': [[1e-2, 1e3],
               [0.055, 0.061],
               [1e-3, 1e3],
               [1e-5, 1e2]],
    'dists' : ['logunif','logunif','logunif','logunif'] #Makes logarithmic uniform distribution
}

# Generate parameter samples
param_values = sobol.sample(problem, 2048) #Sampler generated N * (D+2) inputs, N = num_samples and D = num_vars
#print(param_values)

fit_df = model_evaluate_reversible(d2_rev_dt, param_values)

fit_df["rel_amp_AC"] = fit_df["rel_amp_C"] / fit_df["rel_amp_A"]
fit_df["time_delay_AC"] = fit_df["time_delay_C"] - fit_df["time_delay_A"]
fit_df["rel_amp_AE"] = fit_df["rel_amp_E"] / fit_df["rel_amp_A"]
fit_df["time_delay_AE"] = fit_df["time_delay_E"] - fit_df["time_delay_A"]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 16
#      13 param_values = sobol.sample(problem, 2048) #Sampler generated N * (D+2) inputs, N = num_samples and D = num_vars
#      14 #print(param_values)
# ---> 16 fit_df = model_evaluate_reversible(d2_rev_dt, param_values)
#      18 fit_df["rel_amp_AC"] = fit_df["rel_amp_C"] / fit_df["rel_amp_A"]
#      19 fit_df["time_delay_AC"] = fit_df["time_delay_C"] - fit_df["time_delay_A"]
#
# Cell In[25], line 50, in model_evaluate_reversible(model, param_values)
#      48 for char in s:
#      49     out = sol[:,s.index(char)]
# ---> 50     fit = fit_sin_CSTR(t, out, eq_time, PERIOD)
#      51     if fit[2] > 0.98:
#      52         fit_dict.update({'k1' : klist[0], 'km1' : klist[1], 'k2' : klist[2], 'km2' : klist[3], f'rel_amp_{char}' : fit[0], f'time_delay_{char}' : fit[1]})
#
# Cell In[3], line 30, in fit_sin_CSTR(t, conc, eq_time, PERIOD)
#      27 t_filtered = t[eq_time:]
#      28 conc_filtered = conc[eq_time:]
# ---> 30 res = fit_sin(t_filtered, conc_filtered, PERIOD)
#      31 ypred = sinfunc(t_filtered,res["amp"],res["omega"],res["phase"],res["offset"])
#      32 r2 = r2_score(conc_filtered, ypred)
#
# Cell In[3], line 18, in fit_sin(tt, yy, PERIOD)
#      15 guess_offset = np.mean(yy)
#      16 guess = np.array([guess_amp, PERIOD/2, 0., guess_offset]) #Guess phase = 0; check what works better
# ---> 18 popt, pcov = curve_fit(sinfunc, tt, yy, p0=guess,
#      19                        bounds=((0, (PERIOD-0.0001)/2, -np.inf, -np.inf), (np.inf, (PERIOD+0.0001)/2, np.inf, np.inf)))
#      20 A, w, p, c = popt
#      21 f = w/(2.*np.pi)
#
# File ~\miniconda3\lib\site-packages\scipy\optimize\minpack.py:800, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     797 if 'max_nfev' not in kwargs:
#     798     kwargs['max_nfev'] = kwargs.pop('maxfev', None)
# --> 800 res = least_squares(func, p0, jac=jac, bounds=bounds, method=method,
#     801                     **kwargs)
#     803 if not res.success:
#     804     raise RuntimeError("Optimal parameters not found: " + res.message)
#
# File ~\miniconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py:928, in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     924     result = call_minpack(fun_wrapped, x0, jac_wrapped, ftol, xtol, gtol,
#     925                           max_nfev, x_scale, diff_step)
#     927 elif method == 'trf':
# --> 928     result = trf(fun_wrapped, jac_wrapped, x0, f0, J0, lb, ub, ftol, xtol,
#     929                  gtol, max_nfev, x_scale, loss_function, tr_solver,
#     930                  tr_options.copy(), verbose)
#     932 elif method == 'dogbox':
#     933     if tr_solver == 'lsmr' and 'regularize' in tr_options:
#
# File ~\miniconda3\lib\site-packages\scipy\optimize\_lsq\trf.py:123, in trf(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     119     return trf_no_bounds(
#     120         fun, jac, x0, f0, J0, ftol, xtol, gtol, max_nfev, x_scale,
#     121         loss_function, tr_solver, tr_options, verbose)
#     122 else:
# --> 123     return trf_bounds(
#     124         fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale,
#     125         loss_function, tr_solver, tr_options, verbose)
#
# File ~\miniconda3\lib\site-packages\scipy\optimize\_lsq\trf.py:334, in trf_bounds(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     331     p_h = S.dot(p_S)
#     333 p = d * p_h  # Trust-region solution in the original space.
# --> 334 step, step_h, predicted_reduction = select_step(
#     335     x, J_h, diag_h, g_h, p, p_h, d, Delta, lb, ub, theta)
#     337 x_new = make_strictly_feasible(x + step, lb, ub, rstep=0)
#     338 f_new = fun(x_new)
#
# File ~\miniconda3\lib\site-packages\scipy\optimize\_lsq\trf.py:138, in select_step(x, J_h, diag_h, g_h, p, p_h, d, Delta, lb, ub, theta)
#     136 # Compute the reflected direction.
#     137 r_h = np.copy(p_h)
# --> 138 r_h[hits.astype(bool)] *= -1
#     139 r = d * r_h
#     141 # Restrict trust-region step, such that it hits the bound.
#
# KeyboardInterrupt:

# %%
fit_df.to_excel("k1_km1_k2_km2_2_rev_fixedkm1.xlsx")

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap
import matplotlib as mpl

fit3d_df_pos = fit_df[(fit_df.time_delay_AC > 0) & (fit_df.time_delay_AE > 0)]

fig = plt.figure(figsize=(6,6))

ax = fig.add_subplot(111, projection='3d', proj_type='persp', azim=-35, elev=15, alpha=0.1)

cmap = ListedColormap(sns.color_palette("rocket_r", 256).as_hex())

x = fit3d_df_pos['k2'].to_numpy()
y = fit3d_df_pos['km2'].to_numpy()
z = fit3d_df_pos['k1'].to_numpy()
color = fit3d_df_pos['time_delay_AC'].to_numpy()

sc = ax.scatter(np.log10(x), np.log10(y), np.log10(z), c=color, cmap=cmap, marker='o')
ax.set_xlabel('k2')
ax.set_ylabel('km2')
ax.set_zlabel('k1')

sm = plt.cm.ScalarMappable(cmap= cmap, norm=mpl.colors.Normalize(vmin=0, vmax=100))
#fig.colorbar(sm,ax=ax, orientation='vertical', label='a colorbar label')
cb = fig.colorbar(sc, shrink=0.35, pad=0.1, aspect=15)
cb.set_label("Time delay C-A", labelpad=10)

# %%
fig = plt.figure(figsize=(6,6))

ax = fig.add_subplot(111, projection='3d', proj_type='persp', azim=-35, elev=15, alpha=0.1)

cmap = ListedColormap(sns.color_palette("rocket_r", 256).as_hex())

x = fit3d_df_pos['k2'].to_numpy()
y = fit3d_df_pos['km2'].to_numpy()
z = fit3d_df_pos['k1'].to_numpy()
color = fit3d_df_pos['time_delay_AE'].to_numpy()

sc = ax.scatter(np.log10(x), np.log10(y), np.log10(z), c=color, cmap=cmap, marker='o')
ax.set_xlabel('k2')
ax.set_ylabel('km2')
ax.set_zlabel('k1')

sm = plt.cm.ScalarMappable(cmap= cmap, norm=mpl.colors.Normalize(vmin=0, vmax=100))
#fig.colorbar(sm,ax=ax, orientation='vertical', label='a colorbar label')
cb = fig.colorbar(sc, shrink=0.35, pad=0.1, aspect=15)
cb.set_label("Time delay E-A", labelpad=10)

# %%
fig, ax = plt.subplots(figsize=(3,3))
sns.scatterplot(data=fit3d_df_pos, x="k2", y="km2", hue="time_delay_AC", s=5, linewidth=0)
ax.set_facecolor('#F8F8FB')
ax.legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', markerscale=2)
ax.set_title("Time delay 3-1 (min)", fontsize = 10)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('$k_{2}$', fontsize = 10)
ax.set_ylabel('$k_{-2}$', fontsize = 10)
# Out:
# Text(0, 0.5, '$k_{-2}$')

# %%
fig, ax = plt.subplots(figsize=(3,3))
sns.scatterplot(data=fit3d_df_pos, x="k2", y="km2", hue="time_delay_AE", s=5, linewidth=0)
ax.set_facecolor('#F8F8FB')
ax.legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', markerscale=2)
ax.set_title("Time delay 3-1 (min)", fontsize = 10)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('$k_{2}$', fontsize = 10)
ax.set_ylabel('$k_{-2}$', fontsize = 10)
# Out:
# Text(0, 0.5, '$k_{-2}$')

# %% [markdown]
# ### Probe sensitivity for fixed k-1 and smaller range of ks

# %%
# Define problem
problem = {
    'num_vars': 4,
    'names': ['k1', 'km1', 'k2', 'km2'],
    'bounds': [[1e-1, 4e1],
               [0.055, 0.061],
               [5e0, 1e3],
               [1e-5, 1e2]],
    'dists' : ['logunif','logunif','logunif','logunif'] #Makes logarithmic uniform distribution
}

# Generate parameter samples
param_values = sobol.sample(problem, 2048) #Sampler generated N * (D+2) inputs, N = num_samples and D = num_vars
#print(param_values)

fit_df = model_evaluate_reversible(d2_rev_dt, param_values)

fit_df["rel_amp_AC"] = fit_df["rel_amp_C"] / fit_df["rel_amp_A"]
fit_df["time_delay_AC"] = fit_df["time_delay_C"] - fit_df["time_delay_A"]
fit_df["rel_amp_AE"] = fit_df["rel_amp_E"] / fit_df["rel_amp_A"]
fit_df["time_delay_AE"] = fit_df["time_delay_E"] - fit_df["time_delay_A"]

# %%
fit_df.to_excel("k1_km1_k2_km2_smallerrange_2_rev_fixedkm1_R2_0.95.xlsx")

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap
import matplotlib as mpl

fit3d_df_pos = fit_df[(fit_df.time_delay_AC > -10) & (fit_df.time_delay_AE > -10)]

fig = plt.figure(figsize=(6,6))

ax = fig.add_subplot(111, projection='3d', proj_type='persp', azim=-35, elev=15, alpha=0.1)

cmap = ListedColormap(sns.color_palette("rocket_r", 256).as_hex())

x = fit3d_df_pos['k2'].to_numpy()
y = fit3d_df_pos['km2'].to_numpy()
z = fit3d_df_pos['k1'].to_numpy()
color = fit3d_df_pos['time_delay_AC'].to_numpy()

sc = ax.scatter(np.log10(x), np.log10(y), np.log10(z), c=color, cmap=cmap, marker='o')
ax.set_xlabel('k2')
ax.set_ylabel('km2')
ax.set_zlabel('k1')

sm = plt.cm.ScalarMappable(cmap= cmap, norm=mpl.colors.Normalize(vmin=0, vmax=100))
#fig.colorbar(sm,ax=ax, orientation='vertical', label='a colorbar label')
cb = fig.colorbar(sc, shrink=0.35, pad=0.1, aspect=15)
cb.set_label("Time delay C-A", labelpad=10)

# %%
fig = plt.figure(figsize=(6,6))

ax = fig.add_subplot(111, projection='3d', proj_type='persp', azim=-35, elev=15, alpha=0.1)

cmap = ListedColormap(sns.color_palette("rocket_r", 256).as_hex())

x = fit3d_df_pos['k2'].to_numpy()
y = fit3d_df_pos['km2'].to_numpy()
z = fit3d_df_pos['k1'].to_numpy()
color = fit3d_df_pos['time_delay_AE'].to_numpy()

sc = ax.scatter(np.log10(x), np.log10(y), np.log10(z), c=color, cmap=cmap, marker='o')
ax.set_xlabel('k2')
ax.set_ylabel('km2')
ax.set_zlabel('k1')

sm = plt.cm.ScalarMappable(cmap= cmap, norm=mpl.colors.Normalize(vmin=0, vmax=100))
#fig.colorbar(sm,ax=ax, orientation='vertical', label='a colorbar label')
cb = fig.colorbar(sc, shrink=0.35, pad=0.1, aspect=15)
cb.set_label("Time delay E-A", labelpad=10)

# %%
fig, ax = plt.subplots(figsize=(3,3))
sns.scatterplot(data=fit3d_df_pos, x="k1", y="km2", hue="time_delay_AE", s=5, linewidth=0)
ax.set_facecolor('#F8F8FB')
ax.legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', markerscale=2)
ax.set_title("Time delay 3-1 (min)", fontsize = 10)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('$k_{1}$', fontsize = 10)
ax.set_ylabel('$k_{-2}$', fontsize = 10)
# Out:
# Text(0, 0.5, '$k_{-2}$')

# %%
fig, ax = plt.subplots(figsize=(3,3))
sns.scatterplot(data=fit3d_df_pos, x="k2", y="km2", hue="time_delay_AC", s=5, linewidth=0)
ax.set_facecolor('#F8F8FB')
ax.legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', markerscale=2)
ax.set_title("Time delay 3-1 (min)", fontsize = 10)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('$k_{2}$', fontsize = 10)
ax.set_ylabel('$k_{-2}$', fontsize = 10)
# Out:
# Text(0, 0.5, '$k_{-2}$')

# %%
fig, ax = plt.subplots(figsize=(3,3))
sns.scatterplot(data=fit3d_df_pos, x="k2", y="km2", hue="time_delay_AE", s=5, linewidth=0)
ax.set_facecolor('#F8F8FB')
ax.legend(bbox_to_anchor=(1.02, 1.0), loc='upper left', markerscale=2)
ax.set_title("Time delay 3-1 (min)", fontsize = 10)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('$k_{2}$', fontsize = 10)
ax.set_ylabel('$k_{-2}$', fontsize = 10)
# Out:
# Text(0, 0.5, '$k_{-2}$')

# %%
#objective = rel_amp_AC, rel_amp_AB, time_delay_AC, time_delay_AB
Y = fit_df["time_delay_AC"].to_numpy()

# Perform Sobol analysis
print("Time delay AC")
Si = analyze(problem, Y, calc_second_order=True, print_to_console=True)
# Out:
# Time delay AC
#            ST   ST_conf
# k1   0.576213  0.057260
# km1  0.253182  0.043151
# k2   0.576347  0.066592
# km2  0.771959  0.093329
#            S1   S1_conf
# k1   0.084589  0.054753
# km1  0.014052  0.035281
# k2   0.046247  0.041072
# km2  0.297583  0.054845
#                   S2   S2_conf
# (k1, km1)   0.039070  0.082967
# (k1, k2)    0.119886  0.090844
# (k1, km2)   0.079726  0.087604
# (km1, k2)  -0.006674  0.050505
# (km1, km2) -0.012102  0.047249
# (k2, km2)   0.091847  0.071963
# C:\Users\qduez\miniconda3\lib\site-packages\SALib\util\__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))

# %%
#objective = rel_amp_AC, rel_amp_AB, time_delay_AC, time_delay_AB
Y = fit_df["time_delay_AE"].to_numpy()

# Perform Sobol analysis
print("Time delay AE")
Si = analyze(problem, Y, calc_second_order=True, print_to_console=True)
# Out:
# Time delay AE
#            ST   ST_conf
# k1   0.470031  0.183683
# km1  0.238159  0.117440
# k2   0.544965  0.206902
# km2  0.949095  0.260785
#            S1   S1_conf
# k1   0.019829  0.020995
# km1  0.006242  0.010064
# k2   0.059696  0.090413
# km2  0.354821  0.073005
#                   S2   S2_conf
# (k1, km1)   0.019654  0.039719
# (k1, k2)    0.009575  0.129517
# (k1, km2)   0.073612  0.107383
# (km1, k2)  -0.041779  0.085905
# (km1, km2) -0.032172  0.021022
# (k2, km2)   0.052821  0.148723
# C:\Users\qduez\miniconda3\lib\site-packages\SALib\util\__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))
